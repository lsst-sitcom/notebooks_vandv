# %% [markdown]
# # Tpoint Input File Check – Sample Notebook
#
# This notebook is an example of how to check the input files used for **Tpoint telescope pointing**
#
# - Reading StarTracker metadata (from JSON files downloaded via [Rubin TV](https://usdf-rsp.slac.stanford.edu/rubintv/summit-usdf))
# - Selecting observation dates, cameras (Narrow, Wide, Fast, ComCam), and exposure sequences
# - Querying the Engineering and Facility Database (EFD) for mount telemetry (azimuth and elevation)
# - Visualizing pointing data aligned with exposure windows
# - Comparing timestamp information between RubinTV metadata and FITS file headers
#
# > **Note:** For instructions on how to download and organize StarTracker data, please refer to the companion notebook:
# > **[RubinTV_Pointing_Analysis_using_StarTracker](./RubinTV_Pointing_Analysis_using_StarTracker.ipynb)**
# >
#
# *Notebook from Craig Lage's notebook collection.*
# *Updated by Laura Toribio San Cipriano on April 8, 2025*

# %%
from datetime import date, datetime

import astropy.io.fits as pf
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.time import Time, TimeDelta

from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient

# %% [markdown]
# ### Create a Client
# First, we need to create a client to retrieve datasets from the EFD database.

# %%
# Create an EFD client instance
client = makeEfdClient()

# %% [markdown]
# ## Reading and Processing Star Tracker Data

# %% [markdown]
# ### Getting the Data
#
# If you are unsure how to download, organize, or transfer the necessary **Star Tracker** data, please refer to the notebook:
#
# **RubinTV_Pointing_Analysis_using_StarTracker**
#
# There, you will find detailed step-by-step instructions on:
#
# - Accessing Rubin TV and selecting the different data (Narrow, Wide, or Fast).
# - Downloading the metadata `.json` files for specific observation dates.
# - Uploading files to the USDF environment.
# - Copying them into your scratch directory for efficient processing.
#
# We recommend reading that notebook first if you are running this analysis for the first time!
#
# You can start from the section: **Downloading Star Tracker Data** and follow all the way through to **Copying Data to Scratch Directory**.

# %%
# Modify this path to your own directory where the data is stored  
# Example: DATA_DIR = "/scratch/users/<your_username>/starTracker"
DATA_DIR = "/scratch/users/t/toribio/starTracker"

def read_rubin_tv_json(day_obs, camera):
    """
    Reads a RubinTV JSON file for the given observation day and camera.

    Parameters:
    ----------
    day_obs : int
        Observation day in the format YYYYMMDD.
    camera : str
        Camera type: 'Wide', 'Narrow', or 'AuxTel'.

    Returns:
    -------
    pd.DataFrame
        Transposed DataFrame containing the JSON data.
    """
    # Convert day_obs to datetime and then to astropy Time
    time_obj = Time(datetime.strptime(str(day_obs), "%Y%m%d"))
    date_str = time_obj.strftime("%Y-%m-%d")

    # Define filename based on camera type
    filename_map = {
        "ComCam": f"{DATA_DIR}/comcam_{date_str}.json",
        "Wide": f"{DATA_DIR}/startracker_wide_{date_str}.json",
        "Narrow": f"{DATA_DIR}/startracker_narrow_{date_str}.json",
        "AuxTel": f"{DATA_DIR}/auxtel_{date_str}.json",
        "Fast": f"{DATA_DIR}/startracker_fast_{date_str}.json",
    }

    filename = filename_map.get(camera)

    if not filename:
        raise ValueError(f"Invalid camera type: {camera}")

    try:
        df = pd.read_json(filename).transpose()
        print(f"Loaded file: {filename}")
        return df
    except FileNotFoundError:
        print(f"Error: File not found - {filename}")
        return None

# %% [markdown]
# ## Checking the tpoint input data
# ### One camera, one date only
#
# In this section, we focus on verifying the data that will be used as input for the Tpoint.
# This includes selecting a single **camera** (from available types such as *Narrow*, *Wide*, or *Fast*), a specific **date** of observation, and a particular **sequence range** (exposures).
#
# We will read the metadata previously downloaded from RubinTV, and then identify the relevant telescope telemetry data — **azimuth** and **elevation** — using the EFD (Engineering Facility Database).
#
# This notebook is designed to work with one camera and one observation day at a time. If you want to analyze multiple days or camera types, you will need to run this process iteratively.

# %%
# Select the type of camera between three options: Narrow, Wide and Fast
camera = "Narrow" # "Wide"  "Fast" "Narrow" "ComCam"

# Select the number
num = 102

# Select the date
date = 20230307

# Read the data
df = read_rubin_tv_json(date, camera)
df = df[~df.isnull().any(axis=1)]
# Out:
# Loaded file: /scratch/users/t/toribio/starTracker/startracker_narrow_2023-03-07.json

# %%
# Select the sequence numbers
exp1 = 251
exp2 = 265

# Define the time range using the MJD (Modified Julian Date) values from the data frame.
# Note: 249 and 294 are indices that define the time
# window includes a bit before and after the selected exposures.
start_time = Time(df.loc[249]["MJD"], format="mjd", scale="tai")
end_time = Time(df.loc[294]["MJD"], format="mjd", scale="tai")

# Get all azimuth and elevation position within a particular time range
az_MTM = await client.select_time_series(
    "lsst.sal.MTMount.azimuth", ["actualPosition"], start_time.utc, end_time.utc
)
el_MTM = await client.select_time_series(
    "lsst.sal.MTMount.elevation", ["actualPosition"], start_time.utc, end_time.utc
)

# Plot the azimuth data
ax1 = az_MTM.plot(color="blue")
ax1.set_title(f"StarTracker {camera} {date}, SeqNums {exp1}-{exp2}, Azimuth")

# Plot the elevation data
ax2 = el_MTM.plot(color="blue")
ax2.set_title(f"StarTracker {camera} {date}, SeqNums {exp1}-{exp2}, Elevation")

# Retrieve timing and exposure info for the first selected sequence number
row1 = df.loc[exp1]
time1 = Time(row1["MJD"], format="mjd", scale="tai")
exp_time1 = row1["Exposure Time"]

# Define the plot window start time: 30 seconds before exposure start
start_plot = (
    time1
    - TimeDelta(exp_time1 / 2.0, format="sec")
    - TimeDelta(30.0, format="sec")
)
    
# Retrieve timing and exposure info for the second selected sequence number
row2 = df.loc[exp2]
time2 = Time(row2["MJD"], format="mjd", scale="tai")
exp_time2 = row2["Exposure Time"]

# Define the plot window end time: 30 seconds after exposure end
end_plot = (
    time2
    + TimeDelta(exp_time2 / 2.0, format="sec")
    + TimeDelta(30.0, format="sec")
)

# Set x-axis limits to span from just before the first exposure to just after the last one
ax1.set_xlim(start_plot.utc.isot, end_plot.utc.isot)
ax1.set_ylim(-45.0, -35.0)

ax2.set_xlim(start_plot.utc.isot, end_plot.utc.isot)

# For each exposure in the selected range, draw vertical lines marking start and end times
for seq_num in df.index.values.tolist():
    if seq_num < exp1 or seq_num > exp2:
        continue

    row = df.loc[seq_num]
    time = Time(row["MJD"], format="mjd", scale="tai")
    exp_time = row["Exposure Time"]

    start_exp = time - TimeDelta(exp_time / 2.0, format="sec")
    end_exp = time + TimeDelta(exp_time / 2.0, format="sec")

    ax1.axvline(start_exp.utc.isot, color="green", linestyle="--")
    ax1.axvline(end_exp.utc.isot, color="red", linestyle="--")
    ax2.axvline(start_exp.utc.isot, color="green", linestyle="--")
    ax2.axvline(end_exp.utc.isot, color="red", linestyle="--")

# Add labeled lines
ax1.axvline(start_exp.utc.isot, color="green", linestyle="--", label="ExpStart")
ax1.axvline(end_exp.utc.isot, color="red", linestyle="--", label="ExpEnd")
ax2.axvline(start_exp.utc.isot, color="green", linestyle="--", label="ExpStart")
ax2.axvline(end_exp.utc.isot, color="red", linestyle="--", label="ExpEnd")

ax1.legend()
ax2.legend()

# %%
# Select the sequence numbers
exp1 = 255

# Convert the observation date (YYYYMMDD) to an astropy Time object
time_obj = Time(datetime.strptime(str(date), "%Y%m%d"))

# Extract year, month, and day from the Time object
year = time_obj.datetime.year
month = time_obj.datetime.month
day = time_obj.datetime.day

# Build the path and filename for the FITS file
path = f"/sdf/data/rubin/offline/s3-backup/lfa/GenericCamera/{num}/{year}/{month:02}/{day:02}/"
filename = path + f"GC{num}_O_{date}_{exp1:06}.fits"

# Open the FITS file and extract the header
hdulist = pf.open(filename)
header = hdulist[0].header

# Convert DATE-BEG and DATE-END from header to astropy Time (TAI scale)
date_beg = Time(header["DATE-BEG"], scale="tai")
date_end = Time(header["DATE-END"], scale="tai")

# Define time range to query EFD telemetry based on MJD values
start_time = Time(df.loc[249]["MJD"], format="mjd", scale="tai")
end_time = Time(df.loc[294]["MJD"], format="mjd", scale="tai")

# Query azimuth and elevation actual position data from EFD
az_MTM = await client.select_time_series(
    "lsst.sal.MTMount.azimuth",
    ["actualPosition"],
    start_time.utc,
    end_time.utc,
)

el_MTM = await client.select_time_series(
    "lsst.sal.MTMount.elevation",
    ["actualPosition"],
    start_time.utc,
    end_time.utc,
)

# Plot the elevation data
fig = plt.figure(figsize=(16, 4))
ax1 = el_MTM.plot(color="blue")
ax1.set_title(f"StarTracker {camera} {date}, SeqNum {exp1}, Elevation")

# Retrieve timing and exposure info for the first selected sequence number
row = df.loc[exp1]
time = Time(row["MJD"], format="mjd", scale="tai")
exp_time = row["Exposure Time"]

# Compute exposure start and end times
start_exp = time - TimeDelta(exp_time / 2.0, format="sec")
end_exp = time + TimeDelta(exp_time / 2.0, format="sec")

# Print exposure time window (UTC)
print(f"Start_Exp = {start_exp.utc.isot}, End_exp = {end_exp.utc.isot}")

# Define plot window slightly before and after exposure
start_plot = time - TimeDelta(exp_time / 2.0, format="sec") - TimeDelta(2.0, format="sec")
end_plot = time + TimeDelta(exp_time / 2.0, format="sec") + TimeDelta(2.0, format="sec")
ax1.set_xlim(start_plot.utc.isot, end_plot.utc.isot)

# Add vertical lines for exposure start/end and timestamps from various sources
ax1.axvline(start_exp.utc.isot, color="green", linestyle="--", label="ExpStart")
ax1.axvline(end_exp.utc.isot, color="red", linestyle="--", label="ExpEnd")
ax1.axvline(time.utc.isot, color="cyan", linestyle="--", label="RubinTV MJD")
ax1.axvline(date_beg.utc.isot, color="orange", linestyle="-.", label="Header DATE-BEG")
ax1.axvline(date_end.utc.isot, color="magenta", linestyle="-.", label="Header DATE-END")

# Display legend
ax1.legend()

# Annotate with explanation of what the green/red lines represent
ax1.text(
    (start_exp + TimeDelta(0.2, format="sec")).utc.isot,
    30.0,
    "Using the average value between \nthe red and green lines",
    color="black",
)
# Out:
# Start_Exp = 2023-03-08T02:25:27.253, End_exp = 2023-03-08T02:25:31.253
# Text(2023-03-08T02:25:27.453, 30.0, 'Using the average value between \nthe red and green lines')

# %%
# Print the computed exposure duration in seconds (based on JD difference) 
# and compare it to the reported exposure time from metadata
print((end_exp.jd - start_exp.jd) * 86400.0, exp_time)

# %%
# Print the columns of the dataframe
df.columns

# %%
# Visualizate the histogram of the RMS scatter arcsec data
plt.hist(df['RMS scatter arcsec'].values)

# %% [markdown]
# From Craig Lage's notebook collection

# %%
import numpy as np
from datetime import date
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import astropy.io.fits as pf
from astropy.time import Time, TimeDelta
from lsst_efd_client import EfdClient
#from lsst.sitcom.vandv.efd import create_efd_client
from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient

# %%
client = create_efd_client()

# %%
def  readRubinTV_json(date, camera):
    year = int(date/10000)
    month = int((date - 10000 * year)/100)
    day = int((date - 10000 * year - 100 * month))
    if camera == 'Wide':
        filename = f'/scratch/cslage/starTracker/startracker-wide_{year}-{month:02}-{day:02}.json'
    elif camera == 'Narrow':
        filename = f'/scratch/cslage/starTracker/startracker_{year}-{month:02}-{day:02}.json'
    elif camera == 'AuxTel':
        filename = f'/scratch/cslage/starTracker/auxtel_{year}-{month:02}-{day:02}.json'
    df = pd.read_json(filename)
    df = df.transpose()
    print(filename)
    return df

# %% [markdown]
# ## Checking the tpoint input data
# ### One camera, one date only

# %%
[camera, num] = ['Narrow', 102]
date = 20230307
year = int(date/10000)
month = int((date - 10000 * year)/100)
day = int((date - 10000 * year - 100 * month))
df = readRubinTV_json(date, camera)
df = df[~df.isnull().any(axis=1)]

exp1 = 251
exp2 = 265

start_time = Time(df.loc[249]['MJD'], format='mjd', scale='tai')
end_time = Time(df.loc[294]['MJD'], format='mjd', scale='tai')
azMTM = await client.select_time_series('lsst.sal.MTMount.azimuth', \
                                ['actualPosition'],  start_time.utc, end_time.utc)
elMTM = await client.select_time_series('lsst.sal.MTMount.elevation', \
                                ['actualPosition'],  start_time.utc, end_time.utc) 
#fig = plt.figure(figsize=(16,4))
ax1 = azMTM.plot(color='blue')
ax1.set_title(f"StarTracker Narrow 20220307, SeqNums {exp1}-{exp2}, Azimuth")
ax2 = elMTM.plot(color='blue')
ax2.set_title(f"StarTracker Narrow 20220307, SeqNums {exp1}-{exp2}, Elevation")
row1 = df.loc[exp1]
time1 = Time(row1['MJD'], format='mjd', scale='tai')
expTime1 = row1['Exposure Time']
start_plot = time1 - TimeDelta(expTime1/2.0, format='sec') - TimeDelta(30.0, format='sec')
row2 = df.loc[exp2]
time2 = Time(row2['MJD'], format='mjd', scale='tai')
expTime2 = row2['Exposure Time']
end_plot = time2 + TimeDelta(expTime2/2.0, format='sec') + TimeDelta(30.0, format='sec')
ax1.set_xlim(start_plot.utc.isot, end_plot.utc.isot)

ax1.set_ylim(-45.0, -35.0)
ax2.set_xlim(start_plot.utc.isot, end_plot.utc.isot)
for seqNum in df.index.values.tolist():
    if seqNum < exp1 or seqNum > exp2:
        continue
    row = df.loc[seqNum]
    time = Time(row['MJD'], format='mjd', scale='tai')
    expTime = row['Exposure Time']
    start_exp = time - TimeDelta(expTime/2.0, format='sec')
    end_exp = time + TimeDelta(expTime/2.0, format='sec')
    #print(seqNum, start_exp.isot, end_exp.isot)
    ax1.axvline(start_exp.utc.isot, color='green', linestyle='--')
    ax1.axvline(end_exp.utc.isot, color='red', linestyle='--')
    ax2.axvline(start_exp.utc.isot, color='green', linestyle='--')
    ax2.axvline(end_exp.utc.isot, color='red', linestyle='--')
ax1.axvline(start_exp.utc.isot, color='green', linestyle='--', label='ExpStart')
ax1.axvline(end_exp.utc.isot, color='red', linestyle='--', label='ExpEnd')
ax2.axvline(start_exp.utc.isot, color='green', linestyle='--', label='ExpStart')
ax2.axvline(end_exp.utc.isot, color='red', linestyle='--', label='ExpEnd')
ax1.legend()
ax2.legend()

# %%
[camera, num] = ['Narrow', 102]
date = 20230307
year = int(date/10000)
month = int((date - 10000 * year)/100)
day = int((date - 10000 * year - 100 * month))
df = readRubinTV_json(date, camera)
df = df[~df.isnull().any(axis=1)]
exp1 = 255
path = f"/project/GenericCamera/{num}/{year}/{month:02}/{day:02}/"
filename = path + f"GC{num}_O_{date}_{exp1:06}.fits"
hdulist = pf.open(filename)
header = hdulist[0].header
dateBeg = Time(header['DATE-BEG'], scale='tai')
dateEnd = Time(header['DATE-END'], scale='tai')

start_time = Time(df.loc[249]['MJD'], format='mjd', scale='tai')
end_time = Time(df.loc[294]['MJD'], format='mjd', scale='tai')
azMTM = await client.select_time_series('lsst.sal.MTMount.azimuth', \
                                ['actualPosition'],  start_time.utc, end_time.utc)
elMTM = await client.select_time_series('lsst.sal.MTMount.elevation', \
                                ['actualPosition'],  start_time.utc, end_time.utc) 
fig = plt.figure(figsize=(16,4))
ax1 = elMTM.plot(color='blue')
ax1.set_title(f"StarTracker Narrow 20220307, SeqNum {exp1}, Elevation")

row = df.loc[exp1]
time = Time(row['MJD'], format='mjd', scale='tai')
expTime = row['Exposure Time']
start_exp = time - TimeDelta(expTime/2.0, format='sec')
end_exp = time + TimeDelta(expTime/2.0, format='sec')
print(f"Start_Exp = {start_exp.utc.isot}, End_exp = {end_exp.utc.isot}")
start_plot = time - TimeDelta(expTime/2.0, format='sec') - TimeDelta(2.0, format='sec')
end_plot = time + TimeDelta(expTime/2.0, format='sec') + TimeDelta(2.0, format='sec')
ax1.set_xlim(start_plot.utc.isot, end_plot.utc.isot)
ax1.axvline(start_exp.utc.isot, color='green', linestyle='--', label='ExpStart')
ax1.axvline(end_exp.utc.isot, color='red', linestyle='--', label='ExpEnd')

ax1.axvline(time.utc.isot, color='cyan', linestyle='--', label='RubinTV MJD')
ax1.axvline(dateBeg.utc.isot, color='orange', linestyle='-.', label='Header DATE-BEG')
ax1.axvline(dateEnd.utc.isot, color='magenta', linestyle='-.', label='Header DATE-END')
ax1.legend()
ax1.text((start_exp+TimeDelta(0.2, format='sec')).utc.isot, 30.0, "Using the average value between \nthe read and green lines", color="black")

# %%
print((dateEnd.jd-dateBeg.jd)*86400.0, expTime)

# %%
df.columns

# %%
plt.hist(df['RMS scatter arcsec'].values)
