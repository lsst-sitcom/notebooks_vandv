# %% [markdown]
# # Comparing MTMount Accelerometers to Accelerations from Encoders
#
# This code compares acceleration measurements from MTMount accelerometers
# with acceleration values derived from encoders. The comparison is performed
# in both the azimuth and elevation directions to analyze system dynamics.
#
#
# Authors:
# - Craig Lage (22-Mar-23)
# - Edited by Elana Urbach
# - Edited by Craig Lage
# - Last edited by Laura Toribio (17-Mar-25)

# %%
import asyncio
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.time import Time, TimeDelta
from scipy.interpolate import UnivariateSpline

from lsst_efd_client.efd_helper import merge_packed_time_series
from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
# Temporary workaround to suppress FutureWarning from lsst_efd_client.
# The warning is related to pandas Series indexing behavior changes:
# "Series.__getitem__ treating keys as positions is deprecated..."
# This does not affect the functionality of the code, but future updates to lsst_efd_client
# may require revisiting this issue.

# %% [markdown]
# ##  Functions for calculating the accelerations

# %%
# Define the fields related to acceleration along different axes
base_fields = ["accelerationX", "accelerationY", "accelerationZ"]

# List of sensor names
sensor_names = [
    "SST top end ring +x -y",
    "SST top end ring -x -y",
    "SST spider spindle",
    "SST M2 surrogate"
]

def locations(sensor_name):
    """Returns the sensor's location coordinates and computed radii.

        Returns:
    list: A list containing the following elements:
        - x (float): X-coordinate of the sensor.
        - y (float): Y-coordinate of the sensor.
        - z (float): Z-coordinate of the sensor.
        - r_theta (float): Computed radius in the YZ plane (sqrt(y^2 + z^2)).
        - r_phi (float): Computed radius in the XYZ space (sqrt(x^2 + y^2 + z^2)).
    """
    sensor_positions = {
        "SST top end ring +x -y": (3.876, -3.696, 4.65),
        "SST top end ring -x -y": (-3.786, -3.786, 4.653),
        "SST spider spindle": (-1.275, 0.602, 5.383),
        "SST M2 surrogate": (-1.882, 0.0, 4.342)
    }

    x, y, z = sensor_positions.get(sensor_name, (0, 0, 0))
    r_theta = np.sqrt(z**2 + y**2)
    r_phi = np.sqrt(z**2 + y**2 + x**2)
    
    return [x, y, z, r_theta, r_phi]

def encoder_accels(az, el, start_slew, in_pos):
    """
    Calculates encoder accelerations using smoothing and derivatives.

    Returns:
    list: A list containing the following elements:
        - times_az (ndarray): Array of interpolated timestamps for azimuth.
        - accels_az (ndarray): Array of computed azimuth accelerations in times_az.
        - times_el (ndarray): Array of interpolated timestamps for elevation.
        - accels_el (ndarray): Array of computed elevation accelerations in times_el.
    """
    smoothing_factor = 0.2  # For spline smoothing
    kernel_size = 200
    kernel = np.ones(kernel_size) / kernel_size

    az = az[(az["timestamp"] > (start_slew - 2.0)) & (az["timestamp"] < (in_pos + 1.0))]
    el = el[(el["timestamp"] > (start_slew - 2.0)) & (el["timestamp"] < (in_pos + 1.0))]
    
    az_vs = az["actualVelocity"].values 
    az_xs = az["timestamp"].values - az["timestamp"].values[0]
    el_vs = el["actualVelocity"].values 
    el_xs = el["timestamp"].values - el["timestamp"].values[0]
    
    times_az = np.linspace(az_xs[0], az_xs[-1], len(az_xs) * 100)
    times_el = np.linspace(el_xs[0], el_xs[-1], len(el_xs) * 100)

    az_vel_spline1 = UnivariateSpline(az_xs, az_vs, s=0)
    smoothed_az_vel = np.convolve(az_vel_spline1(times_az), kernel, mode="same")
    az_vel_spline = UnivariateSpline(times_az, smoothed_az_vel, s=smoothing_factor)

    az_acc_spline1 = az_vel_spline.derivative(n=1)
    smoothed_az_acc = np.convolve(az_acc_spline1(times_az), kernel, mode="same")
    az_acc_spline = UnivariateSpline(times_az, smoothed_az_acc, s=smoothing_factor)

    accels_az = az_acc_spline(times_az)
    
    el_vel_spline1 = UnivariateSpline(el_xs, el_vs, s=0)
    smoothed_el_vel = np.convolve(el_vel_spline1(times_el), kernel, mode="same")
    el_vel_spline = UnivariateSpline(times_el, smoothed_el_vel, s=smoothing_factor)

    el_acc_spline1 = el_vel_spline.derivative(n=1)
    smoothed_el_acc = np.convolve(el_acc_spline1(times_el), kernel, mode="same")
    el_acc_spline = UnivariateSpline(times_el, smoothed_el_acc, s=smoothing_factor)

    accels_el = el_acc_spline(times_el)

    return [times_az, accels_az, times_el, accels_el]


def accelerometer_accels(packed_dataframe, el, az, sensor_name, start_slew, in_pos):
    """
    Rotates accelerometer accelerations into AzEl space.

    Returns:
    DataFrame: A DataFrame containing the following columns:
        - 'AccelerationElevation' (float): Computed acceleration in the elevation direction.
        - 'AccelerationAzimuth' (float): Computed acceleration in the azimuth direction.
        - 'times' (float): Timestamps relative to the start of the movement.
        - 'Elevation' (float): Elevation angles in degrees.
        - 'Azimuth' (float): Azimuth angles in degrees.
    """
    gravity = 9.5
    rolling_avg = 100  # Smoothing factor for noisy data
    
    sub_df = packed_dataframe.loc[packed_dataframe.sensorName == sensor_name]
    sub_df = sub_df[(sub_df['timestamp'] > (start_slew - 2.0)) & (sub_df['timestamp'] < (in_pos + 1.0))]
    
    el = el[(el['timestamp'] > (start_slew - 2.0)) & (el['timestamp'] < (in_pos + 1.0))]
    elevations = np.array(
        el.actualPosition.iloc[
            np.argmin(
                np.abs(
                    np.subtract(
                        np.array(el.timestamp),
                        np.expand_dims(np.array(sub_df.timestamp), 0).T
                    )
                ),
                axis=1
            )
        ]
    )
    unpacked_elevations = np.repeat(elevations, 200) * np.pi / 180.0  # Convert to radians
    
    az = az[(az['timestamp'] > (start_slew - 2.0)) & (az['timestamp'] < (in_pos + 1.0))]
    azimuth = np.array(
        az.actualPosition.iloc[
            np.argmin(
                np.abs(
                    np.subtract(
                        np.array(az.timestamp),
                        np.expand_dims(np.array(sub_df.timestamp), 0).T
                    )
                ),
                axis=1
            )
        ]
    )
    unpacked_azimuth = np.repeat(azimuth, 200)
    
    [x_coord, y_coord, z_coord, r_theta, r_phi] = locations(sensor_name)  # Get sensor coordinates
    r_phi_axis = np.sqrt(
        (z_coord * np.cos(unpacked_elevations) - y_coord * np.sin(unpacked_elevations))**2 + x_coord**2
    )
    
    for base_field in base_fields:
        df = merge_packed_time_series(
            sub_df, base_field, stride=1,
            ref_timestamp_col="timestamp", fmt='unix_tai', scale='tai'
        )
        
        if base_field == 'accelerationX':
            az_el_accel_df = pd.DataFrame(
                data={
                    'AccelerationElevation': np.zeros(len(df.index)),
                    'AccelerationAzimuth': np.zeros(len(df.index)),
                    'times': df['times'] - df['times'].values[0]
                }
            )
            az_el_accel_df['Elevation'] = unpacked_elevations * 180 / np.pi
            az_el_accel_df['Azimuth'] = unpacked_azimuth
            az_el_accel_df['AccelerationAzimuth'] -= (
                np.array(df['accelerationX']) *
                (z_coord * np.cos(unpacked_elevations) - y_coord * np.sin(unpacked_elevations)) /
                (r_phi_axis**2)
            ) * 180.0 / np.pi
        
        if base_field == 'accelerationY':
            df['accelerationY'] -= gravity * np.cos(unpacked_elevations)
            az_el_accel_df['AccelerationElevation'] += (
                np.array(df['accelerationY']) * z_coord / (r_theta**2)
                ) * 180.0 / np.pi
            az_el_accel_df['AccelerationAzimuth'] -= (
                np.array(df['accelerationY']) * np.sin(unpacked_elevations) *
                (x_coord / (r_phi_axis**2))
                ) * 180.0 / np.pi
        
        if base_field == 'accelerationZ':
            df['accelerationZ'] -= gravity * np.sin(unpacked_elevations)
            az_el_accel_df['AccelerationElevation'] -= (
                np.array(df['accelerationZ']) * y_coord / (r_theta**2)
                ) * 180.0 / np.pi
            az_el_accel_df['AccelerationAzimuth'] += (
                np.array(df['accelerationZ']) * np.cos(unpacked_elevations) *
                (x_coord / (r_phi_axis**2))
                ) * 180.0 / np.pi
    
    # Remove mean to account for gravity removal
    az_el_accel_df['AccelerationAzimuth'] -= az_el_accel_df['AccelerationAzimuth'].mean()
    az_el_accel_df['AccelerationElevation'] -= az_el_accel_df['AccelerationElevation'].mean()
    
    # Apply rolling average for smoothing
    az_el_accel_df['AccelerationAzimuth'] = (
        az_el_accel_df['AccelerationAzimuth'].rolling(rolling_avg, center=True).sum() / rolling_avg
    )
    az_el_accel_df['AccelerationElevation'] = (
        az_el_accel_df['AccelerationElevation'].rolling(rolling_avg, center=True).sum() / rolling_avg
    )
    
    return az_el_accel_df

# %% [markdown]
# ##  Get all of the data for the selected times

# %%
# Create an EFD client instance
client = makeEfdClient()

# %% [markdown]
# The time is defined using the `Time` class from `astropy`, which follows the ISO 8601 format:
#
# **YYYY-MM-DD HH:MM:SSZ**, where:
# - `YYYY` is the year
# - `MM` is the month
# - `DD` is the day
# - `HH:MM:SS` represents hours, minutes, and seconds in 24-hour format
# - `Z` indicates that the time is in Coordinated Universal Time (UTC)

# %%
# Define the time range using UTC format
start = Time("2023-03-25T01:26:29", scale='utc')
end = Time("2023-03-25T01:46:02", scale='utc')

# %%
packed_dataframe = await client.select_time_series(
    "lsst.sal.ESS.accelerometer", # Topic containing accelerometer telemetry data
    ["*"],                        # Select all available fields
    start,                        # Start time for data retrieval
    end                           # End time for data retrieval
)

az = await client.select_time_series(
    'lsst.sal.MTMount.azimuth',
    ['actualPosition', 'actualVelocity', 'timestamp'],  
    start, 
    end
)

el = await client.select_time_series(
    'lsst.sal.MTMount.elevation',
     ['actualPosition', 'actualVelocity', 'timestamp'],  
    start,
    end
)

az_track = await client.select_time_series(
    'lsst.sal.MTMount.command_trackTarget',
    ['azimuth', 'taiTime'],  
    start, 
    end
)

el_track = await client.select_time_series(
    'lsst.sal.MTMount.command_trackTarget',
    ['elevation', 'taiTime'], 
    start,
    end
)   

azPos = await client.select_time_series(
    'lsst.sal.MTMount.logevent_azimuthInPosition',
    ['inPosition', 'private_kafkaStamp'],  
    start, 
    end
)

azPos = azPos[azPos['inPosition']] # Select only the True values

elPos = await client.select_time_series(
    'lsst.sal.MTMount.logevent_elevationInPosition',
    ['inPosition', 'private_kafkaStamp'], 
    start,
    end
)

elPos = elPos[elPos['inPosition']] # Select only the True values

slew_starts = await client.select_time_series(
    'lsst.sal.MTPtg.command_raDecTarget',
    ['ra', 'declination', 'private_sndStamp'],  
    start, 
    end
)

# %% [markdown]
# ## Now find the slew times and pair them up

# %%
# Find all of the time stamps
# Start with start_slew times

azs = az_track.values[:, 0]
els = el_track.values[:, 0]
times = az_track.values[:, 1]

start_slew_times_1 = []
slew_dist_1 = []

for i in range(1, len(az_track)):
    az_shift = abs(azs[i] - azs[i - 1])
    el_shift = abs(els[i] - els[i - 1])

    if az_shift > 0.1 or el_shift > 0.1:
        start_slew_times_1.append(times[i])

        az_shift_mod = az_shift * np.cos(np.radians(els[i]))
        shift = np.sqrt(el_shift**2 + az_shift_mod**2)
        slew_dist_1.append(shift)

print(len(start_slew_times_1))

# Now in position timestamps
in_pos_1 = []
az_pos_values = azPos.values[:, 1]
el_pos_values = elPos.values[:, 1]

for i in range(len(azPos)):
    in_pos_1.append(max(az_pos_values[i], el_pos_values[i]))

print(len(in_pos_1))

# Now pair them up
pair_min = 1.0
pair_max = 6.0

start_slew_times = []
slew_dist = []
slew_times = []
in_pos = []

for start_time in start_slew_times_1:
    for pos_time in in_pos_1:
        delta_t = pos_time - start_time

        if pair_min < delta_t < pair_max:
            in_pos.append(pos_time)
            start_slew_times.append(start_time)
            slew_times.append(delta_t)
            slew_dist.append(slew_dist_1[start_slew_times_1.index(start_time)])

# Convert lists to arrays
time_deltas = np.zeros(len(start_slew_times))
slew_dist = np.array(slew_dist)
slew_times = np.array(slew_times)

slew_stamps = Time(slew_starts.private_sndStamp.to_numpy(), format="unix_tai", scale="utc")

for i, start_slew_time in enumerate(start_slew_times):
    start_time_obj = Time(start_slew_time, format="unix_tai", scale="utc")
    k = np.argmin(np.abs((start_time_obj - slew_stamps).to_value("s")))

    time_delta = start_time_obj - slew_stamps[k]
    time_deltas[i] = time_delta.to_value("s")
    start_slew_times[i] = slew_stamps[k].value

slew_times += time_deltas

print(len(in_pos), len(start_slew_times), len(slew_times), len(slew_dist))

# %% [markdown]
# ## Now run the accelerations and plot the comparisons

# %%
for index in range(len(in_pos)):
    # Create a figure with a specified size
    plt.figure(figsize=(16, 4))
    plt.subplots_adjust(hspace=0.5)

    # Convert time to ISO format and generate a timestamp
    ip_time = Time(in_pos[index], format="unix_tai", scale="utc").isot
    timestamp = ip_time.split(".")[0].replace("-", "").replace(":", "")

    # Set the main title
    plt.suptitle(f"EFD vs Accelerometer Accelerations - {ip_time}")

    # Loop through each sensor and plot elevation/azimuth acceleration
    for sensor_name in sensor_names:
        az_el_accel_df = accelerometer_accels(
            packed_dataframe, el, az, sensor_name, start_slew_times[index], in_pos[index]
        )

        # Plot Elevation Acceleration
        plt.subplot(1, 3, 1)
        plt.title("Elevation")
        plt.plot(
            az_el_accel_df["times"],
            az_el_accel_df["AccelerationElevation"],
            label=str(sensor_name),
        )

        # Plot Azimuth Acceleration
        plt.subplot(1, 3, 2)
        plt.title("Azimuth")
        plt.plot(
            az_el_accel_df["times"],
            az_el_accel_df["AccelerationAzimuth"],
            label=str(sensor_name),
        )

        # Optional plots (commented out)
        """
        plt.subplot(2, 3, 4)
        plt.title("Elevation")
        plt.plot(az_el_accel_df["times"], az_el_accel_df["Elevation"], label=str(sensor_name))

        plt.subplot(2, 3, 5)
        plt.title("Azimuth")
        plt.plot(az_el_accel_df["times"], az_el_accel_df["Azimuth"], label=str(sensor_name))
        """

    # Compute encoder accelerations
    times_az, accels_az, times_el, accels_el = encoder_accels(
        az, el, start_slew_times[index], in_pos[index]
    )

    # Plot Encoder Elevation Acceleration
    plt.subplot(1, 3, 1)
    plt.plot(times_el, accels_el, label="MT Encoder", ls="--", lw=2, color="k")
    plt.plot([2.0, 2.0], [np.min(accels_el), np.max(accels_el)], ls=":", color="r", label="Slew start")
    plt.plot(
        [times_el[-1] - 1.0, times_el[-1] - 1.0],
        [np.min(accels_el), np.max(accels_el)],
        ls=":",
        color="g",
        label="InPos",
    )
    plt.xlabel("Time (sec)")
    plt.ylabel("Acceleration (deg/s²)")

    # Plot Encoder Azimuth Acceleration
    plt.subplot(1, 3, 2)
    plt.plot(times_az, accels_az, label="MT Encoder", ls="--", lw=2, color="k")
    plt.plot([2.0, 2.0], [np.min(accels_az), np.max(accels_az)], ls=":", color="r", label="Slew start")
    plt.plot(
        [times_az[-1] - 1.0, times_az[-1] - 1.0],
        [np.min(accels_az), np.max(accels_az)],
        ls=":",
        color="g",
        label="InPos",
    )
    plt.xlabel("Time (sec)")
    plt.ylabel("Acceleration (deg/s²)")

    # Add legend and display plot
    plt.legend(bbox_to_anchor=(1.1, 0.8))
    plt.show()

    # Save the figure (optional)
    # plt.savefig(f"/ltoribio/Accel_Comparison_{timestamp}.png")
