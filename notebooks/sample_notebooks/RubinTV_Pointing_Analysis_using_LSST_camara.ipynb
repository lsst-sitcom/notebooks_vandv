# %% [markdown]
# # LSST Camara Error Analysis and Visualization
#
# This notebook provides a step-by-step guide to working with LSST camara data. It covers the entire process, from downloading the data to performing error analysis and visualization. Specifically, it will:
#
# - Download LSST camara data from Rubin TV, selecting specific observation dates.
# - Transfer the data to USDF for further processing.
# - Read and extract information from the downloaded files.
# - Analyze and visualize RA and DEC errors.

# %% [markdown]
# ## Downloading LSST Camara Data
#
# To analyze the stars tracked, the first step is to access Rubin TV for download the using the following link:
# [Rubin TV - Summit USDF](https://usdf-rsp.slac.stanford.edu/rubintv/summit-usdf)
#
# Once on the Rubin TV page, you can access data from **LSSTCam** by clicking on the corresponding icon.
#
# ### Selecting a Specific Date
#
# To search for data from a specific observation day, click on the **Historical** botton.
#
# You can use the calendar to select the year, month, and day of the data you want to analyze. Suppose we want to download data from **April 15, 2025**. Click on the calendar to select this date.
#
# Once the date is selected, the available data for that day will be displayed.
# ### Downloading the Data
#
# To download the data, click on **Download Metadata**, and a `.json` file containing the information will be downloaded. In this case, the file will be named: lsstcam_2025-04-15.json

# %% [markdown]
# ## Transferring Data to USDF
#
# Now that the data is stored on your local computer, you need to copy it to USDF to be able to use it.
#
# ### Uploading Data to USDF
#
# To do this, you can create a folder named **LSSTCam** inside your `notebooks/` directory and upload the data there. However, you can also place the data in any other directory of your choice.
#
# ### Copying Data to Scratch Directory
#
# For better accessibility and performance, it is recommended to store the data in the **scratch directory**. You can copy the uploaded files to:  `/scratch/users/<your_username>/lsstCam`
#
# Before doing so, make sure that the `lsstCam` folder exists inside your user directory. If it does not exist, create it first using:
#
# ```bash
# mkdir -p /scratch/users/<your_username>/lsstCam
# ```
#
# Now, you can copy the files from notebooks/starTracker/ to the scratch directory by running the following command in the terminal:
#
# ```bash
# cp /home/<your_username>/notebooks/lsstCam/* /scratch/users/<your_username>/lsstCam/
# ```
#
# This will move all the files you uploaded into the starTracker folder in the scratch directory, making them ready for analysis.
#
# We are now ready to start the analysis

# %%
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.time import Time

# %% [markdown]
# ## Reading and Processing Star Tracker Data

# %%
# Modify this path to your own directory where the data is stored  
# Example: DATA_DIR = "/scratch/users/<your_username>/LSSTCam"
DATA_DIR = "/scratch/users/t/toribio/lsstCam"

def read_rubin_tv_json(day_obs, camera):
    """
    Reads a RubinTV JSON file for the given observation day and camera.

    Parameters:
    ----------
    day_obs : int
        Observation day in the format YYYYMMDD.
    camera : str
        Camera type: 'LSSTCam'.

    Returns:
    -------
    pd.DataFrame
        Transposed DataFrame containing the JSON data.
    """
    # Convert day_obs to datetime and then to astropy Time
    time_obj = Time(datetime.strptime(str(day_obs), "%Y%m%d"))
    date_str = time_obj.strftime("%Y-%m-%d")

    # Define filename based on camera type
    filename_map = {
        "ComCam": f"{DATA_DIR}/comcam_{date_str}.json",
        "Wide": f"{DATA_DIR}/startracker_wide_{date_str}.json",
        "Narrow": f"{DATA_DIR}/startracker_narrow_{date_str}.json",
        "AuxTel": f"{DATA_DIR}/auxtel_{date_str}.json",
        "Fast": f"{DATA_DIR}/startracker_fast_{date_str}.json",
        "LSSTCam": f"{DATA_DIR}/lsstcam_{date_str}.json",
    }

    filename = filename_map.get(camera)

    if not filename:
        raise ValueError(f"Invalid camera type: {camera}")

    try:
        df = pd.read_json(filename).transpose()
        print(f"Loaded file: {filename}")
        return df
    except FileNotFoundError:
        print(f"Error: File not found - {filename}")
        return None

# %% [markdown]
# ## Visualise the data

# %% [markdown]
# > **Note for the future**
# > As of the creation date of this notebook (May 20, 2025), the columns `delta Alt (arcsec)` and `delta Az (arcsec)` were not yet implemented in the LSSTCam metadata, but they are expected to be added in the future.
# >
# > This notebook has been designed assuming that these columns will be named `delta Alt (arcsec)` and `delta Az (arcsec)`.
# >
# > Please be aware that if the actual column names differ, the notebook will either fail or be unable to read the required information. In that case, you will need to modify the code in the following section to match the correct column names:
# >
# > ```python
# >
# ># Remove rows with NaN values
# >  df = df.dropna(subset=['delta Ra (arcsec)', 'delta Dec (arcsec)'
# >                          #, 'delta Alt (arcsec)', 'delta Az (arcsec)' # Uncomment this line if these columns are already implemented. And rename them if necessary.
# >                          ] )
# >
# > if camera == "LSSTCam":
# >     ra_col = "delta Ra (arcsec)"
# >     dec_col = "delta Dec (arcsec)"
# >     alt_col = "delta Alt (arcsec)"  # rename them if necessary.
# >     az_col = "delta Az (arcsec)"    # rename them if necessary.
# > else:
# >     continue
# > ```
# >
# > Rename `delta Alt (arcsec)` and `delta Az (arcsec)` accordingly if they appear under different names in the metadata.

# %%
# List of observation dates in YYYYMMDD format
# Modify this list with your own data
dates = [20250415, 20250416, 20250417, 20250418, 20250419, 20250420]


# Select the type of camera
camera = "LSSTCam"

# Variables to store results
x_axis = []
delta_ras = []
delta_decs = []
counter = 1

for day_obs in dates:

    # Read data from RubinTV JSON files
    df = read_rubin_tv_json(day_obs, camera)
    if df is None:
        continue  # Skip if the file does not exist

    # Remove rows with NaN values
    df = df.dropna(subset=['delta Ra (arcsec)', 'delta Dec (arcsec)'
                          #, 'delta Alt (arcsec)', 'delta Az (arcsec)'  # Uncomment this line if these columns are already implemented. And rename them if necessary.
                          ] ) 
    
    for seq_num, row in df.iterrows():
        if camera == "LSSTCam":
            ra_col = "delta Ra (arcsec)"
            dec_col = "delta Dec (arcsec)"
            alt_col = "delta Alt (arcsec)"  # rename them if necessary.
            az_col = "delta Az (arcsec)"    # rename them if necessary.
        else:
            continue 
            
        processed = False
        
        if ra_col in df.columns:
           delta_ra = row[ra_col]
           delta_ra = float(delta_ra)
           delta_ras.append(abs(delta_ra))
           processed = True
          
        if dec_col in df.columns:
           delta_dec = row[dec_col]
           delta_dec = float(delta_dec)
           delta_decs.append(abs(delta_dec))
           processed = True

        if alt_col in df.columns:
           delta_alt = row[alt_col]
           delta_els.append(abs(delta_alt))
           processed = True
        
        if az_col in df.columns:
           delta_az = row[az_col]
           delta_azs.append(abs(delta_az))
           processed = True

        x_axis.append(counter)
    
    counter += 1

# %% [markdown]
# ## RA Error Trend Plot

# %%
# Extend dates list to include the last observation date
plot_dates = dates

# Define x-axis ticks
x_ticks = np.arange(1, len(plot_dates) + 1, 1)

# Create the plot for StarTracker Narrow Azimuth Error Trend
plt.figure(figsize=(8, 6))
plt.title("LSST Camara RA Error Trend")

# Scatter plot of ra errors
plt.scatter(x_axis, delta_ras, color="blue", alpha=0.7, label="RA Error")

# Use logarithmic scale for the y-axis
plt.yscale("log")
plt.ylim(1.0, 1.0e5)

# Set x-axis labels with proper rotation
plt.xticks(x_ticks, plot_dates, rotation=-45)

# Label axes
plt.xlabel("Date")
plt.ylabel("RA Error (arcsec)")

# Show grid and legend for better readability
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Dec Error Trend Plot

# %%
# Extend dates list to include the last observation date
plot_dates = dates

# Define x-axis ticks
x_ticks = np.arange(1, len(plot_dates) + 1, 1)

# Create the plot for StarTracker Narrow Azimuth Error Trend
plt.figure(figsize=(8, 6))
plt.title("LSST Camara Dec Error Trend")

# Scatter plot of dec errors
plt.scatter(x_axis, delta_decs, color="blue", alpha=0.7, label="Dec Error")

# Use logarithmic scale for the y-axis
plt.yscale("log")
plt.ylim(1.0, 1.0e5)

# Set x-axis labels with proper rotation
plt.xticks(x_ticks, plot_dates, rotation=-45)

# Label axes
plt.xlabel("Date")
plt.ylabel("Dec Error (arcsec)")

# Show grid and legend for better readability
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Az Error Trend Plot

# %% [markdown]
# > **Note for the future**
# > The Az Error Trend and Alt Error Trend plots will fail if you try to run them.
# >
# > Please note that in the future, when this information is included in the metadata, it may not be included for the dates analyzed in this notebook, but it may be for other future dates.
# >
# > When the information is available, you don't need to change anything in this section to run these plots.

# %%
# Extend dates list to include the last observation date
plot_dates = dates

# Define x-axis ticks
x_ticks = np.arange(1, len(plot_dates) + 1, 1)

# Create the plot for StarTracker Narrow Azimuth Error Trend
plt.figure(figsize=(8, 6))
plt.title("LSST Camara Az Error Trend")

# Scatter plot of dec errors
plt.scatter(x_axis, delta_azs, color="blue", alpha=0.7, label="Dec Error")

# Use logarithmic scale for the y-axis
plt.yscale("log")
plt.ylim(1.0, 1.0e5)

# Set x-axis labels with proper rotation
plt.xticks(x_ticks, plot_dates, rotation=-45)

# Label axes
plt.xlabel("Date")
plt.ylabel("Az Error (arcsec)")

# Show grid and legend for better readability
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()

# %%
## Alt Error Trend Plot

# %%
# Extend dates list to include the last observation date
plot_dates = dates

# Define x-axis ticks
x_ticks = np.arange(1, len(plot_dates) + 1, 1)

# Create the plot for StarTracker Narrow Azimuth Error Trend
plt.figure(figsize=(8, 6))
plt.title("LSST Camara Alt Error Trend")

# Scatter plot of dec errors
plt.scatter(x_axis, delta_els, color="blue", alpha=0.7, label="Dec Error")

# Use logarithmic scale for the y-axis
plt.yscale("log")
plt.ylim(1.0, 1.0e5)

# Set x-axis labels with proper rotation
plt.xticks(x_ticks, plot_dates, rotation=-45)

# Label axes
plt.xlabel("Date")
plt.ylabel("Alt Error (arcsec)")

# Show grid and legend for better readability
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.tight_layout()

# Display the plot
plt.show()
